# %% [markdown]
# # <font color=blue> Data Visualization

# %% [markdown]
# <font color=blue> **The objective of this project is twofold: to delve into the study of visualization libraries while advancing further in the exploration of Jupyter Notebook and Python. The project encompasses a major dataset and offers a range of exercises involving diverse datasets.** <font>
#
# Several practices will be employed in this study:
#
# 1- Below certain commands, there will be a summary of their meanings.
#
# 2- All text will be written in English.
#
# 3- The data has been extracted from exercises on the Alura platform.
#
# 4- Each dataset will have a summary of its meaning.

# %% [markdown]
# # About
#
# We are entrusted with a dataset encompassing a comprehensive sales report from 2016 to 2019 in our prominent online department store. Our mission is to craft compelling visualizations for various sectors within the store, effectively conveying valuable insights derived from this report.
#
# We have received a dataset that displays the sales report from the years 2016 to 2019, and our goal is to build visualizations that can convey relevant information to other departments within the company.
#
# To achieve this, we need to understand our database and the type of information it provides. Therefore, let's examine what each of the columns in the primary dataset signifies:
#
#  - date_ordered (data_pedido): the date on which the customer placed the product order.
#  - shipping_method (modo_envio): the shipping method specified by the customer.
#  - customer_name (nome_cliente): the name of the customer.
#  - customer_segment (segmento_cliente): the segment to which the customer belongs, either B2B or B2C.
#  - city (cidade): the destination city of the order.
#  - state (estado): the destination state of the order.
#  - region (regiao): the region of the destination state of the order.
#  - department (departamento): the department of the ordered product.
#  - product_type (tipo_produto): the category of the ordered product.
#  - sales (vendas): the sales value of the product.
#  - quantity (quantidade): the quantity ordered for the product.
#  - discount (desconto): the discount provided on the purchase.
#  - profit (lucro): the profit/loss value for the company, considering expenses related to the product.

# %% [markdown]
# # To do List
#
# 1- The sales team needs to know the top 10 largest customers by total sales.
#
# 2- Visualization that allows associating: the total sales revenue and the total profit earned from the types of products sold.
#
# 3- Provide the distribution of orders by region in Brazil.
#
# 4- Find a pattern of product demands per month throughout the year.
#
# 5- Relate the shipping method of the products to the type of customer, based on the sales value obtained.

# %%
import pandas as pd
import numpy as np

primary_data = pd.read_csv('Dados/relatorio_vendas.csv')

primary_data['data_pedido'] = pd.to_datetime(primary_data['data_pedido'])

print("Primary Data size is: {}".format(primary_data.size))
print("Primary Data type is: {}".format(type(primary_data)))
# Out:
# Primary Data size is: 107280
# Primary Data type is: <class 'pandas.core.frame.DataFrame'>

# %%
primary_data.head()
# Out:
#   data_pedido      modo_envio       nome_cliente segmento_cliente  \
# 0  2018-11-09       Econômica    Thiago Silveira              B2C
# 1  2018-11-09       Econômica    Thiago Silveira              B2C
# 2  2018-06-13       Econômica      Giovanna Lima              B2B
# 3  2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
# 4  2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
#
#            cidade          estado   regiao             departamento  \
# 0  Ribeirão Preto       São Paulo  Sudeste  Materiais de construção
# 1  Ribeirão Preto       São Paulo  Sudeste  Materiais de construção
# 2  Rio de Janeiro  Rio de Janeiro  Sudeste  Jardinagem e paisagismo
# 3   Foz do Iguaçu          Paraná      Sul  Materiais de construção
# 4   Foz do Iguaçu          Paraná      Sul  Jardinagem e paisagismo
#
#                 tipo_produto   vendas  quantidade    lucro
# 0               encanamentos   890.66           2   142.51
# 1                ferramentas  2488.60           3   746.58
# 2                   sementes    49.71           2    23.36
# 3  materiais de revestimento  3255.76           5 -1302.31
# 4                      vasos    76.05           2     8.56

# %% [markdown]
# # 1- Top 10 Customers

# %%
top_10_customers = primary_data.groupby(['nome_cliente'])['vendas'].sum().nlargest(10).copy()
top_10_customers = top_10_customers.reset_index()
top_10_customers.columns = ['Client','Sales']
top_10_customers['Rank'] = top_10_customers.index + 1
top_10_customers.set_index('Rank', inplace=True)
top_10_customers
# Out:
#                      Client     Sales
# Rank
# 1       Maria Luiza Almeida  64777.54
# 2           Ana Julia Pinto  51398.95
# 3               Ryan Farias  48178.94
# 4            Heitor da Mata  47610.85
# 5     Maria Clara Gonçalves  46946.42
# 6            Raquel Freitas  44826.26
# 7                Davi Ramos  43769.21
# 8               Amanda Melo  42354.27
# 9            Alexia Ribeiro  41238.84
# 10           Calebe Ribeiro  41056.70

# %%
# Creating object styler

s = top_10_customers.style
s.format({'Sales': 'R$ {:,.2f}'})
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_75c41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75c41_level0_col0" class="col_heading level0 col0" >Client</th>
#       <th id="T_75c41_level0_col1" class="col_heading level0 col1" >Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75c41_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_75c41_row0_col0" class="data row0 col0" >Maria Luiza Almeida</td>
#       <td id="T_75c41_row0_col1" class="data row0 col1" >R$ 64,777.54</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_75c41_row1_col0" class="data row1 col0" >Ana Julia Pinto</td>
#       <td id="T_75c41_row1_col1" class="data row1 col1" >R$ 51,398.95</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_75c41_row2_col0" class="data row2 col0" >Ryan Farias</td>
#       <td id="T_75c41_row2_col1" class="data row2 col1" >R$ 48,178.94</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_75c41_row3_col0" class="data row3 col0" >Heitor da Mata</td>
#       <td id="T_75c41_row3_col1" class="data row3 col1" >R$ 47,610.85</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_75c41_row4_col0" class="data row4 col0" >Maria Clara Gonçalves</td>
#       <td id="T_75c41_row4_col1" class="data row4 col1" >R$ 46,946.42</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_75c41_row5_col0" class="data row5 col0" >Raquel Freitas</td>
#       <td id="T_75c41_row5_col1" class="data row5 col1" >R$ 44,826.26</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_75c41_row6_col0" class="data row6 col0" >Davi Ramos</td>
#       <td id="T_75c41_row6_col1" class="data row6 col1" >R$ 43,769.21</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_75c41_row7_col0" class="data row7 col0" >Amanda Melo</td>
#       <td id="T_75c41_row7_col1" class="data row7 col1" >R$ 42,354.27</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_75c41_row8_col0" class="data row8 col0" >Alexia Ribeiro</td>
#       <td id="T_75c41_row8_col1" class="data row8 col1" >R$ 41,238.84</td>
#     </tr>
#     <tr>
#       <th id="T_75c41_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_75c41_row9_col0" class="data row9 col0" >Calebe Ribeiro</td>
#       <td id="T_75c41_row9_col1" class="data row9 col1" >R$ 41,056.70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 2- Total sales / Total revenue

# %%
# Creating dataframe

sales_revenue = primary_data.groupby(['tipo_produto'])[['vendas','lucro']].sum()
sales_revenue.columns = ['Sales','Revenue']
sales_revenue.index.name = 'Product Type'

# Creating styler

product_styler = sales_revenue.style
product_styler.format('R$ {:,.2f}')\
              .highlight_max(color='lightgreen')\
              .highlight_min(color='#F16165')
# Out:
# <style type="text/css">
# #T_03c3b_row9_col1, #T_03c3b_row11_col0 {
#   background-color: #F16165;
# }
# #T_03c3b_row13_col1, #T_03c3b_row14_col0 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_03c3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03c3b_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_03c3b_level0_col1" class="col_heading level0 col1" >Revenue</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03c3b_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_03c3b_row0_col0" class="data row0 col0" >R$ 82,680.87</td>
#       <td id="T_03c3b_row0_col1" class="data row0 col1" >R$ 19,880.86</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row1" class="row_heading level0 row1" >encanamentos</th>
#       <td id="T_03c3b_row1_col0" class="data row1 col0" >R$ 373,224.39</td>
#       <td id="T_03c3b_row1_col1" class="data row1 col1" >R$ -11,243.39</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row2" class="row_heading level0 row2" >equipamentos de limpeza</th>
#       <td id="T_03c3b_row2_col0" class="data row2 col0" >R$ 542,304.55</td>
#       <td id="T_03c3b_row2_col1" class="data row2 col1" >R$ 17,448.30</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row3" class="row_heading level0 row3" >ferramentas</th>
#       <td id="T_03c3b_row3_col0" class="data row3 col0" >R$ 995,159.43</td>
#       <td id="T_03c3b_row3_col1" class="data row3 col1" >R$ 82,042.91</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row4" class="row_heading level0 row4" >ferramentas automotivas</th>
#       <td id="T_03c3b_row4_col0" class="data row4 col0" >R$ 502,109.33</td>
#       <td id="T_03c3b_row4_col1" class="data row4 col1" >R$ 126,660.54</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row5" class="row_heading level0 row5" >ferramentas de jardinagem</th>
#       <td id="T_03c3b_row5_col0" class="data row5 col0" >R$ 648,880.47</td>
#       <td id="T_03c3b_row5_col1" class="data row5 col1" >R$ 106,408.80</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row6" class="row_heading level0 row6" >fertilizantes</th>
#       <td id="T_03c3b_row6_col0" class="data row6 col0" >R$ 53,144.55</td>
#       <td id="T_03c3b_row6_col1" class="data row6 col1" >R$ 22,509.86</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row7" class="row_heading level0 row7" >iluminação</th>
#       <td id="T_03c3b_row7_col0" class="data row7 col0" >R$ 275,229.82</td>
#       <td id="T_03c3b_row7_col1" class="data row7 col1" >R$ 40,531.09</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row8" class="row_heading level0 row8" >materiais de paisagismo</th>
#       <td id="T_03c3b_row8_col0" class="data row8 col0" >R$ 150,552.80</td>
#       <td id="T_03c3b_row8_col1" class="data row8 col1" >R$ -3,823.67</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row9" class="row_heading level0 row9" >materiais de revestimento</th>
#       <td id="T_03c3b_row9_col0" class="data row9 col0" >R$ 629,656.41</td>
#       <td id="T_03c3b_row9_col1" class="data row9 col1" >R$ -57,737.23</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row10" class="row_heading level0 row10" >mobiliário de exterior</th>
#       <td id="T_03c3b_row10_col0" class="data row10 col0" >R$ 328,932.37</td>
#       <td id="T_03c3b_row10_col1" class="data row10 col1" >R$ 53,569.57</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row11" class="row_heading level0 row11" >mudas</th>
#       <td id="T_03c3b_row11_col0" class="data row11 col0" >R$ 8,811.69</td>
#       <td id="T_03c3b_row11_col1" class="data row11 col1" >R$ 2,762.88</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row12" class="row_heading level0 row12" >pesticidas</th>
#       <td id="T_03c3b_row12_col0" class="data row12 col0" >R$ 244,958.41</td>
#       <td id="T_03c3b_row12_col1" class="data row12 col1" >R$ 106,688.03</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row13" class="row_heading level0 row13" >peças de reposição</th>
#       <td id="T_03c3b_row13_col0" class="data row13 col0" >R$ 486,907.88</td>
#       <td id="T_03c3b_row13_col1" class="data row13 col1" >R$ 182,297.32</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row14" class="row_heading level0 row14" >pneus</th>
#       <td id="T_03c3b_row14_col0" class="data row14 col0" >R$ 1,022,430.50</td>
#       <td id="T_03c3b_row14_col1" class="data row14 col1" >R$ 134,923.09</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row15" class="row_heading level0 row15" >sementes</th>
#       <td id="T_03c3b_row15_col0" class="data row15 col0" >R$ 39,980.49</td>
#       <td id="T_03c3b_row15_col1" class="data row15 col1" >R$ 17,730.06</td>
#     </tr>
#     <tr>
#       <th id="T_03c3b_level0_row16" class="row_heading level0 row16" >vasos</th>
#       <td id="T_03c3b_row16_col0" class="data row16 col0" >R$ 696,045.39</td>
#       <td id="T_03c3b_row16_col1" class="data row16 col1" >R$ 67,887.28</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Creating gradient

product_styler = sales_revenue.style
product_styler.format('R$ {:,.2f}').background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_30ad9_row0_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_30ad9_row0_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_30ad9_row1_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_30ad9_row1_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_30ad9_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_30ad9_row2_col1, #T_30ad9_row10_col0, #T_30ad9_row15_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_30ad9_row3_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_30ad9_row3_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_30ad9_row4_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_30ad9_row4_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_30ad9_row5_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_30ad9_row5_col1, #T_30ad9_row12_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_30ad9_row6_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_30ad9_row6_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_30ad9_row7_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_30ad9_row7_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_30ad9_row8_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_30ad9_row8_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_30ad9_row9_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_30ad9_row9_col1, #T_30ad9_row11_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_30ad9_row10_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_30ad9_row11_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_30ad9_row12_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_30ad9_row13_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_30ad9_row13_col1, #T_30ad9_row14_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_30ad9_row14_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_30ad9_row15_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_30ad9_row16_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_30ad9_row16_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# </style>
# <table id="T_30ad9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30ad9_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_30ad9_level0_col1" class="col_heading level0 col1" >Revenue</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30ad9_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_30ad9_row0_col0" class="data row0 col0" >R$ 82,680.87</td>
#       <td id="T_30ad9_row0_col1" class="data row0 col1" >R$ 19,880.86</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row1" class="row_heading level0 row1" >encanamentos</th>
#       <td id="T_30ad9_row1_col0" class="data row1 col0" >R$ 373,224.39</td>
#       <td id="T_30ad9_row1_col1" class="data row1 col1" >R$ -11,243.39</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row2" class="row_heading level0 row2" >equipamentos de limpeza</th>
#       <td id="T_30ad9_row2_col0" class="data row2 col0" >R$ 542,304.55</td>
#       <td id="T_30ad9_row2_col1" class="data row2 col1" >R$ 17,448.30</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row3" class="row_heading level0 row3" >ferramentas</th>
#       <td id="T_30ad9_row3_col0" class="data row3 col0" >R$ 995,159.43</td>
#       <td id="T_30ad9_row3_col1" class="data row3 col1" >R$ 82,042.91</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row4" class="row_heading level0 row4" >ferramentas automotivas</th>
#       <td id="T_30ad9_row4_col0" class="data row4 col0" >R$ 502,109.33</td>
#       <td id="T_30ad9_row4_col1" class="data row4 col1" >R$ 126,660.54</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row5" class="row_heading level0 row5" >ferramentas de jardinagem</th>
#       <td id="T_30ad9_row5_col0" class="data row5 col0" >R$ 648,880.47</td>
#       <td id="T_30ad9_row5_col1" class="data row5 col1" >R$ 106,408.80</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row6" class="row_heading level0 row6" >fertilizantes</th>
#       <td id="T_30ad9_row6_col0" class="data row6 col0" >R$ 53,144.55</td>
#       <td id="T_30ad9_row6_col1" class="data row6 col1" >R$ 22,509.86</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row7" class="row_heading level0 row7" >iluminação</th>
#       <td id="T_30ad9_row7_col0" class="data row7 col0" >R$ 275,229.82</td>
#       <td id="T_30ad9_row7_col1" class="data row7 col1" >R$ 40,531.09</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row8" class="row_heading level0 row8" >materiais de paisagismo</th>
#       <td id="T_30ad9_row8_col0" class="data row8 col0" >R$ 150,552.80</td>
#       <td id="T_30ad9_row8_col1" class="data row8 col1" >R$ -3,823.67</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row9" class="row_heading level0 row9" >materiais de revestimento</th>
#       <td id="T_30ad9_row9_col0" class="data row9 col0" >R$ 629,656.41</td>
#       <td id="T_30ad9_row9_col1" class="data row9 col1" >R$ -57,737.23</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row10" class="row_heading level0 row10" >mobiliário de exterior</th>
#       <td id="T_30ad9_row10_col0" class="data row10 col0" >R$ 328,932.37</td>
#       <td id="T_30ad9_row10_col1" class="data row10 col1" >R$ 53,569.57</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row11" class="row_heading level0 row11" >mudas</th>
#       <td id="T_30ad9_row11_col0" class="data row11 col0" >R$ 8,811.69</td>
#       <td id="T_30ad9_row11_col1" class="data row11 col1" >R$ 2,762.88</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row12" class="row_heading level0 row12" >pesticidas</th>
#       <td id="T_30ad9_row12_col0" class="data row12 col0" >R$ 244,958.41</td>
#       <td id="T_30ad9_row12_col1" class="data row12 col1" >R$ 106,688.03</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row13" class="row_heading level0 row13" >peças de reposição</th>
#       <td id="T_30ad9_row13_col0" class="data row13 col0" >R$ 486,907.88</td>
#       <td id="T_30ad9_row13_col1" class="data row13 col1" >R$ 182,297.32</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row14" class="row_heading level0 row14" >pneus</th>
#       <td id="T_30ad9_row14_col0" class="data row14 col0" >R$ 1,022,430.50</td>
#       <td id="T_30ad9_row14_col1" class="data row14 col1" >R$ 134,923.09</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row15" class="row_heading level0 row15" >sementes</th>
#       <td id="T_30ad9_row15_col0" class="data row15 col0" >R$ 39,980.49</td>
#       <td id="T_30ad9_row15_col1" class="data row15 col1" >R$ 17,730.06</td>
#     </tr>
#     <tr>
#       <th id="T_30ad9_level0_row16" class="row_heading level0 row16" >vasos</th>
#       <td id="T_30ad9_row16_col0" class="data row16 col0" >R$ 696,045.39</td>
#       <td id="T_30ad9_row16_col1" class="data row16 col1" >R$ 67,887.28</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Creating dictionary

header = {
    'selector': 'th',
    'props': 'font-weight: bold; font-family: Arial; text-align: center; text-transform: capitalize;'
}

product_styler.format('R$ {:,.2f}').background_gradient(cmap='Greens')
product_styler.set_table_styles([header], overwrite = False)
# Out:
# <style type="text/css">
# #T_dbe88 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   text-transform: capitalize;
# }
# #T_dbe88 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   text-transform: capitalize;
# }
# #T_dbe88_row0_col0 {
#   background-color: #edf8e9;
#   color: #000000;
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_dbe88_row0_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_dbe88_row1_col0 {
#   background-color: #a5db9f;
#   color: #000000;
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_dbe88_row1_col1 {
#   background-color: #d5efcf;
#   color: #000000;
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_dbe88_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_dbe88_row2_col1, #T_dbe88_row10_col0, #T_dbe88_row15_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_dbe88_row3_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_dbe88_row3_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_dbe88_row4_col0 {
#   background-color: #79c67a;
#   color: #000000;
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_dbe88_row4_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_dbe88_row5_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_dbe88_row5_col1, #T_dbe88_row12_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_dbe88_row6_col0 {
#   background-color: #f1faee;
#   color: #000000;
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_dbe88_row6_col1 {
#   background-color: #aedea7;
#   color: #000000;
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_dbe88_row7_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_dbe88_row7_col1 {
#   background-color: #95d391;
#   color: #000000;
#   background-color: #95d391;
#   color: #000000;
# }
# #T_dbe88_row8_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_dbe88_row8_col1 {
#   background-color: #cdecc7;
#   color: #000000;
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_dbe88_row9_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_dbe88_row9_col1, #T_dbe88_row11_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_dbe88_row10_col1 {
#   background-color: #81ca81;
#   color: #000000;
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_dbe88_row11_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_dbe88_row12_col0 {
#   background-color: #cbebc5;
#   color: #000000;
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_dbe88_row13_col0 {
#   background-color: #7fc97f;
#   color: #000000;
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_dbe88_row13_col1, #T_dbe88_row14_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_dbe88_row14_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_dbe88_row15_col0 {
#   background-color: #f3faf0;
#   color: #000000;
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_dbe88_row16_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_dbe88_row16_col1 {
#   background-color: #6bc072;
#   color: #000000;
#   background-color: #6bc072;
#   color: #000000;
# }
# </style>
# <table id="T_dbe88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbe88_level0_col0" class="col_heading level0 col0" >Sales</th>
#       <th id="T_dbe88_level0_col1" class="col_heading level0 col1" >Revenue</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Product Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbe88_level0_row0" class="row_heading level0 row0" >decoração de jardim</th>
#       <td id="T_dbe88_row0_col0" class="data row0 col0" >R$ 82,680.87</td>
#       <td id="T_dbe88_row0_col1" class="data row0 col1" >R$ 19,880.86</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row1" class="row_heading level0 row1" >encanamentos</th>
#       <td id="T_dbe88_row1_col0" class="data row1 col0" >R$ 373,224.39</td>
#       <td id="T_dbe88_row1_col1" class="data row1 col1" >R$ -11,243.39</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row2" class="row_heading level0 row2" >equipamentos de limpeza</th>
#       <td id="T_dbe88_row2_col0" class="data row2 col0" >R$ 542,304.55</td>
#       <td id="T_dbe88_row2_col1" class="data row2 col1" >R$ 17,448.30</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row3" class="row_heading level0 row3" >ferramentas</th>
#       <td id="T_dbe88_row3_col0" class="data row3 col0" >R$ 995,159.43</td>
#       <td id="T_dbe88_row3_col1" class="data row3 col1" >R$ 82,042.91</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row4" class="row_heading level0 row4" >ferramentas automotivas</th>
#       <td id="T_dbe88_row4_col0" class="data row4 col0" >R$ 502,109.33</td>
#       <td id="T_dbe88_row4_col1" class="data row4 col1" >R$ 126,660.54</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row5" class="row_heading level0 row5" >ferramentas de jardinagem</th>
#       <td id="T_dbe88_row5_col0" class="data row5 col0" >R$ 648,880.47</td>
#       <td id="T_dbe88_row5_col1" class="data row5 col1" >R$ 106,408.80</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row6" class="row_heading level0 row6" >fertilizantes</th>
#       <td id="T_dbe88_row6_col0" class="data row6 col0" >R$ 53,144.55</td>
#       <td id="T_dbe88_row6_col1" class="data row6 col1" >R$ 22,509.86</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row7" class="row_heading level0 row7" >iluminação</th>
#       <td id="T_dbe88_row7_col0" class="data row7 col0" >R$ 275,229.82</td>
#       <td id="T_dbe88_row7_col1" class="data row7 col1" >R$ 40,531.09</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row8" class="row_heading level0 row8" >materiais de paisagismo</th>
#       <td id="T_dbe88_row8_col0" class="data row8 col0" >R$ 150,552.80</td>
#       <td id="T_dbe88_row8_col1" class="data row8 col1" >R$ -3,823.67</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row9" class="row_heading level0 row9" >materiais de revestimento</th>
#       <td id="T_dbe88_row9_col0" class="data row9 col0" >R$ 629,656.41</td>
#       <td id="T_dbe88_row9_col1" class="data row9 col1" >R$ -57,737.23</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row10" class="row_heading level0 row10" >mobiliário de exterior</th>
#       <td id="T_dbe88_row10_col0" class="data row10 col0" >R$ 328,932.37</td>
#       <td id="T_dbe88_row10_col1" class="data row10 col1" >R$ 53,569.57</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row11" class="row_heading level0 row11" >mudas</th>
#       <td id="T_dbe88_row11_col0" class="data row11 col0" >R$ 8,811.69</td>
#       <td id="T_dbe88_row11_col1" class="data row11 col1" >R$ 2,762.88</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row12" class="row_heading level0 row12" >pesticidas</th>
#       <td id="T_dbe88_row12_col0" class="data row12 col0" >R$ 244,958.41</td>
#       <td id="T_dbe88_row12_col1" class="data row12 col1" >R$ 106,688.03</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row13" class="row_heading level0 row13" >peças de reposição</th>
#       <td id="T_dbe88_row13_col0" class="data row13 col0" >R$ 486,907.88</td>
#       <td id="T_dbe88_row13_col1" class="data row13 col1" >R$ 182,297.32</td>
#     </tr>
#     <tr>
#       <th id="T_dbe88_level0_row14" class="row_heading level0 row14" >pneus</th>
#       <td id="T_dbe88_row14_col0" c

# %% [markdown]
# # 3- Orders by region in Brazil

# %%
# Create Dataframe

order_by_region = pd.DataFrame(primary_data['regiao'].value_counts())
order_by_region.columns = ['Number of Orders']
order_by_region.index.name = 'Region'
percent = order_by_region['Number of Orders'].to_numpy()
percent = 100*percent / percent.sum()
order_by_region['Percent'] = percent.round(2)

order_by_region
# Out:
#               Number of Orders  Percent
# Region
# Sudeste                   4470    50.00
# Nordeste                  2075    23.21
# Centro-Oeste               983    11.00
# Norte                      779     8.71
# Sul                        633     7.08

# %%
# Styling the dataframe

styler_region = order_by_region.style

header = {
    'selector': 'th',
    'props': 'font-weight: bold; font-family: Arial; text-align: right;background-color: white',
    
}


cells = {
    'selector':'td',
    'props':'background-color: white;'
}

styler_region.set_table_styles([header,cells])

styler_region.format({'Percent':'{:.2f}%'})\
             .bar(subset = 'Percent', vmin=0, vmax=100.0, color='#9CD33B')
# Out:
# <style type="text/css">
# #T_6cdf9 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   background-color: white;
# }
# #T_6cdf9 td {
#   background-color: white;
# }
# #T_6cdf9_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 50.0%, transparent 50.0%);
# }
# #T_6cdf9_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 23.2%, transparent 23.2%);
# }
# #T_6cdf9_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 11.0%, transparent 11.0%);
# }
# #T_6cdf9_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 8.7%, transparent 8.7%);
# }
# #T_6cdf9_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9CD33B 7.1%, transparent 7.1%);
# }
# </style>
# <table id="T_6cdf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cdf9_level0_col0" class="col_heading level0 col0" >Number of Orders</th>
#       <th id="T_6cdf9_level0_col1" class="col_heading level0 col1" >Percent</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cdf9_level0_row0" class="row_heading level0 row0" >Sudeste</th>
#       <td id="T_6cdf9_row0_col0" class="data row0 col0" >4470</td>
#       <td id="T_6cdf9_row0_col1" class="data row0 col1" >50.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6cdf9_level0_row1" class="row_heading level0 row1" >Nordeste</th>
#       <td id="T_6cdf9_row1_col0" class="data row1 col0" >2075</td>
#       <td id="T_6cdf9_row1_col1" class="data row1 col1" >23.21%</td>
#     </tr>
#     <tr>
#       <th id="T_6cdf9_level0_row2" class="row_heading level0 row2" >Centro-Oeste</th>
#       <td id="T_6cdf9_row2_col0" class="data row2 col0" >983</td>
#       <td id="T_6cdf9_row2_col1" class="data row2 col1" >11.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6cdf9_level0_row3" class="row_heading level0 row3" >Norte</th>
#       <td id="T_6cdf9_row3_col0" class="data row3 col0" >779</td>
#       <td id="T_6cdf9_row3_col1" class="data row3 col1" >8.71%</td>
#     </tr>
#     <tr>
#       <th id="T_6cdf9_level0_row4" class="row_heading level0 row4" >Sul</th>
#       <td id="T_6cdf9_row4_col0" class="data row4 col0" >633</td>
#       <td id="T_6cdf9_row4_col1" class="data row4 col1" >7.08%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 4- Pattern of product demands

# %%
# Creating dataframe to find a temporal order

months = primary_data.copy()
months = months.sort_values('data_pedido')
months['months'] = months['data_pedido'].dt.strftime('%Y - %b')
months = months.reset_index(drop=True)
months
# Out:
#      data_pedido      modo_envio         nome_cliente segmento_cliente  \
# 0     2016-01-04  Entrega padrão   Ana Júlia Monteiro              B2C
# 1     2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 2     2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 3     2016-01-05  Entrega padrão  Maria Cecília Jesus              B2B
# 4     2016-01-06  Entrega padrão      Marcelo Rezende              B2C
# ...          ...             ...                  ...              ...
# 8935  2019-12-31  Entrega padrão           Lara Pinto              B2C
# 8936  2019-12-31  Entrega padrão           Lara Pinto              B2C
# 8937  2019-12-31  Entrega padrão           Lara Pinto              B2C
# 8938  2019-12-31  Entrega padrão         Cauê Martins              B2B
# 8939  2019-12-31  Entrega padrão         Cauê Martins              B2B
#
#               cidade            estado        regiao             departamento  \
# 0     Belo Horizonte      Minas Gerais       Sudeste  Jardinagem e paisagismo
# 1           Botucatu         São Paulo       Sudeste  Jardinagem e paisagismo
# 2           Botucatu         São Paulo       Sudeste  Jardinagem e paisagismo
# 3           Botucatu         São Paulo       Sudeste  Jardinagem e paisagismo
# 4           Brasília  Distrito Federal  Centro-Oeste  Jardinagem e paisagismo
# ...              ...               ...           ...                      ...
# 8935       São Paulo         São Paulo       Sudeste  Jardinagem e paisagismo
# 8936       São Paulo         São Paulo       Sudeste               Automotivo
# 8937       São Paulo         São Paulo       Sudeste  Materiais de construção
# 8938          Osasco         São Paulo       Sudeste  Jardinagem e paisagismo
# 8939          Osasco         São Paulo       Sudeste  Jardinagem e paisagismo
#
#                    tipo_produto   vendas  quantidade   lucro      months
# 0                    pesticidas    55.92           2   18.87  2016 - Jan
# 1     ferramentas de jardinagem    12.04           2  -18.66  2016 - Jan
# 2                         vasos   927.30           3 -220.23  2016 - Jan
# 3                      sementes    40.07           3   14.52  2016 - Jan
# 4           decoração de jardim    66.42           3   16.61  2016 - Jan
# ...                         ...      ...         ...     ...         ...
# 8935  ferramentas de jardinagem   179.44           3   67.29  2019 - Dec
# 8936                      pneus   309.16           7    9.27  2019 - Dec
# 8937               encanamentos  1098.66           4   41.20  2019 - Dec
# 8938  ferramentas de jardinagem    47.27           2   15.36  2019 - Dec
# 8939  ferramentas de jardinagem    70.45           2   22.01  2019 - Dec
#
# [8940 rows x 13 columns]

# %%
# Creating pivot table

month_sales = months.pivot_table(index= 'departamento', columns= 'months', values= 'quantidade', aggfunc= 'sum', sort= False)
month_sales
# Out:
# months                   2016 - Apr  2016 - Aug  2016 - Dec  2016 - Feb  \
# departamento
# Jardinagem e paisagismo         323         339         525          87
# Automotivo                      107          95         154          20
# Materiais de construção          69         101         269          23
#
# months                   2016 - Jan  2016 - Jul  2016 - Jun  2016 - Mar  \
# departamento
# Jardinagem e paisagismo         161         348         273         277
# Automotivo                       45          91          83          46
# Materiais de construção          60         104         114         102
#
# months                   2016 - May  2016 - Nov  ...  2019 - Dec  2019 - Feb  \
# departamento                                     ...
# Jardinagem e paisagismo         270         716  ...         989         205
# Automotivo                       81         236  ...         252          63
# Materiais de construção          91         213  ...         395          67
#
# months                   2019 - Jan  2019 - Jul  2019 - Jun  2019 - Mar  \
# departamento
# Jardinagem e paisagismo         361         423         490         458
# Automotivo                      109         168         170         167
# Materiais de construção          83         162         151         107
#
# months                   2019 - May  2019 - Nov  2019 - Oct  2019 - Sep
# departamento
# Jardinagem e paisagismo         542         946         617         929
# Automotivo                      150         331         205         280
# Materiais de construção         172         312         213         282
#
# [3 rows x 48 columns]

# %%
# Creating styler

styler_month = month_sales.style
styler_month.set_sticky(axis= 'index')

columns = {
    'selector': '.col_heading',
    'props': 'font-weight: normal; font-family: Arial;'
}

tables = {
    'selector': 'td, th',
    'props': 'text-align: left;'
}

index = {
    'selector': '.index_name',
    'props': 'font-weight: bold; font-family: Arial; text-align: right;'
}


styler_month.set_table_styles([columns, tables, index], overwrite=False)
# Out:
# <style type="text/css">
# #T_24c84 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_24c84 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_24c84 .col_heading {
#   font-weight: normal;
#   font-family: Arial;
# }
# #T_24c84 td {
#   text-align: left;
# }
# #T_24c84  th {
#   text-align: left;
# }
# #T_24c84 .index_name {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
# }
# </style>
# <table id="T_24c84">
#   <thead>
#     <tr>
#       <th class="index_name level0" >months</th>
#       <th id="T_24c84_level0_col0" class="col_heading level0 col0" >2016 - Apr</th>
#       <th id="T_24c84_level0_col1" class="col_heading level0 col1" >2016 - Aug</th>
#       <th id="T_24c84_level0_col2" class="col_heading level0 col2" >2016 - Dec</th>
#       <th id="T_24c84_level0_col3" class="col_heading level0 col3" >2016 - Feb</th>
#       <th id="T_24c84_level0_col4" class="col_heading level0 col4" >2016 - Jan</th>
#       <th id="T_24c84_level0_col5" class="col_heading level0 col5" >2016 - Jul</th>
#       <th id="T_24c84_level0_col6" class="col_heading level0 col6" >2016 - Jun</th>
#       <th id="T_24c84_level0_col7" class="col_heading level0 col7" >2016 - Mar</th>
#       <th id="T_24c84_level0_col8" class="col_heading level0 col8" >2016 - May</th>
#       <th id="T_24c84_level0_col9" class="col_heading level0 col9" >2016 - Nov</th>
#       <th id="T_24c84_level0_col10" class="col_heading level0 col10" >2016 - Oct</th>
#       <th id="T_24c84_level0_col11" class="col_heading level0 col11" >2016 - Sep</th>
#       <th id="T_24c84_level0_col12" class="col_heading level0 col12" >2017 - Apr</th>
#       <th id="T_24c84_level0_col13" class="col_heading level0 col13" >2017 - Aug</th>
#       <th id="T_24c84_level0_col14" class="col_heading level0 col14" >2017 - Dec</th>
#       <th id="T_24c84_level0_col15" class="col_heading level0 col15" >2017 - Feb</th>
#       <th id="T_24c84_level0_col16" class="col_heading level0 col16" >2017 - Jan</th>
#       <th id="T_24c84_level0_col17" class="col_heading level0 col17" >2017 - Jul</th>
#       <th id="T_24c84_level0_col18" class="col_heading level0 col18" >2017 - Jun</th>
#       <th id="T_24c84_level0_col19" class="col_heading level0 col19" >2017 - Mar</th>
#       <th id="T_24c84_level0_col20" class="col_heading level0 col20" >2017 - May</th>
#       <th id="T_24c84_level0_col21" class="col_heading level0 col21" >2017 - Nov</th>
#       <th id="T_24c84_level0_col22" class="col_heading level0 col22" >2017 - Oct</th>
#       <th id="T_24c84_level0_col23" class="col_heading level0 col23" >2017 - Sep</th>
#       <th id="T_24c84_level0_col24" class="col_heading level0 col24" >2018 - Apr</th>
#       <th id="T_24c84_level0_col25" class="col_heading level0 col25" >2018 - Aug</th>
#       <th id="T_24c84_level0_col26" class="col_heading level0 col26" >2018 - Dec</th>
#       <th id="T_24c84_level0_col27" class="col_heading level0 col27" >2018 - Feb</th>
#       <th id="T_24c84_level0_col28" class="col_heading level0 col28" >2018 - Jan</th>
#       <th id="T_24c84_level0_col29" class="col_heading level0 col29" >2018 - Jul</th>
#       <th id="T_24c84_level0_col30" class="col_heading level0 col30" >2018 - Jun</th>
#       <th id="T_24c84_level0_col31" class="col_heading level0 col31" >2018 - Mar</th>
#       <th id="T_24c84_level0_col32" class="col_heading level0 col32" >2018 - May</th>
#       <th id="T_24c84_level0_col33" class="col_heading level0 col33" >2018 - Nov</th>
#       <th id="T_24c84_level0_col34" class="col_heading level0 col34" >2018 - Oct</th>
#       <th id="T_24c84_level0_col35" class="col_heading level0 col35" >2018 - Sep</th>
#       <th id="T_24c84_level0_col36" class="col_heading level0 col36" >2019 - Apr</th>
#       <th id="T_24c84_level0_col37" class="col_heading level0 col37" >2019 - Aug</th>
#       <th id="T_24c84_level0_col38" class="col_heading level0 col38" >2019 - Dec</th>
#       <th id="T_24c84_level0_col39" class="col_heading level0 col39" >2019 - Feb</th>
#       <th id="T_24c84_level0_col40" class="col_heading level0 col40" >2019 - Jan</th>
#       <th id="T_24c84_level0_col41" class="col_heading level0 col41" >2019 - Jul</th>
#       <th id="T_24c84_level0_col42" class="col_heading level0 col42" >2019 - Jun</th>
#       <th id="T_24c84_level0_col43" class="col_heading level0 col43" >2019 - Mar</th>
#       <th id="T_24c84_level0_col44" class="col_heading level0 col44" >2019 - May</th>
#       <th id="T_24c84_level0_col45" class="col_heading level0 col45" >2019 - Nov</th>
#       <th id="T_24c84_level0_col46" class="col_heading level0 col46" >2019 - Oct</th>
#       <th id="T_24c84_level0_col47" class="col_heading level0 col47" >2019 - Sep</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >departamento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#       <th class="blank col40" >&nbsp;</th>
#       <th class="blank col41" >&nbsp;</th>
#       <th class="blank col42" >&nbsp;</th>
#       <th class="blank col43" >&nbsp;</th>
#       <th class="blank col44" >&nbsp;</th>
#       <th class="blank col45" >&nbsp;</th>
#       <th class="blank col46" >&nbsp;</th>
#       <th class="blank col47" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24c84_level0_row0" class="row_heading level0 row0" >Jardinagem e paisagismo</th>
#       <td id="T_24c84_row0_col0" class="data row0 col0" >323</td>
#       <td id="T_24c84_row0_col1" class="data row0 col1" >339</td>
#       <td id="T_24c84_row0_col2" class="data row0 col2" >525</td>
#       <td id="T_24c84_row0_col3" class="data row0 col3" >87</td>
#       <td id="T_24c84_row0_col4" class="data row0 col4" >161</td>
#       <td id="T_24c84_row0_col5" class="data row0 col5" >348</td>
#       <td id="T_24c84_row0_col6" class="data row0 col6" >273</td>
#       <td id="T_24c84_row0_col7" class="data row0 col7" >277</td>
#       <td id="T_24c84_row0_col8" class="data row0 col8" >270</td>
#       <td id="T_24c84_row0_col9" class="data row0 col9" >716</td>
#       <td id="T_24c84_row0_col10" class="data row0 col10" >276</td>
#       <td id="T_24c84_row0_col11" class="data row0 col11" >549</td>
#       <td id="T_24c84_row0_col12" class="data row0 col12" >271</td>
#       <td id="T_24c84_row0_col13" class="data row0 col13" >322</td>
#       <td id="T_24c84_row0_col14" class="data row0 col14" >628</td>
#       <td id="T_24c84_row0_col15" clas

# %% [markdown]
# # 5- Shipping method based on customer

# %%
# Creating pivot table

shipping_customer = primary_data.pivot_table(index='segmento_cliente', columns='modo_envio', values='vendas', aggfunc='sum')
shipping_customer['Total'] = shipping_customer.sum(axis=1)
shipping_customer.loc['Total'] = shipping_customer.sum()
shipping_customer
# Out:
# modo_envio         24 horas   Econômica  Entrega padrão  Envio rápido  \
# segmento_cliente
# B2B               217466.05   718462.52      1884740.78     602049.56
# B2C               182531.80   729176.13      2248286.96     498295.55
# Total             399997.85  1447638.65      4133027.74    1100345.11
#
# modo_envio             Total
# segmento_cliente
# B2B               3422718.91
# B2C               3658290.44
# Total             7081009.35

# %%
# Creating styler object

sales_customer = shipping_customer.style.format('{:,.2f}')
sales_customer

# Changing table visualization

table = {
    'selector':'td, th:not(.index_name)',
    'props': 'font-weight: normal; font-family: Arial; text-align: center; background-color: white'
}

index = {
    'selector': '.index_name',
    'props': 'font-weight: normal; font-align: right; font-style: italic; color: #696969'
}

sales_customer.set_table_styles([table,index])
# Out:
# <style type="text/css">
# #T_22cbd td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_22cbd  th:not(.index_name) {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_22cbd .index_name {
#   font-weight: normal;
#   font-align: right;
#   font-style: italic;
#   color: #696969;
# }
# </style>
# <table id="T_22cbd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_22cbd_level0_col0" class="col_heading level0 col0" >24 horas</th>
#       <th id="T_22cbd_level0_col1" class="col_heading level0 col1" >Econômica</th>
#       <th id="T_22cbd_level0_col2" class="col_heading level0 col2" >Entrega padrão</th>
#       <th id="T_22cbd_level0_col3" class="col_heading level0 col3" >Envio rápido</th>
#       <th id="T_22cbd_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22cbd_level0_row0" class="row_heading level0 row0" >B2B</th>
#       <td id="T_22cbd_row0_col0" class="data row0 col0" >217,466.05</td>
#       <td id="T_22cbd_row0_col1" class="data row0 col1" >718,462.52</td>
#       <td id="T_22cbd_row0_col2" class="data row0 col2" >1,884,740.78</td>
#       <td id="T_22cbd_row0_col3" class="data row0 col3" >602,049.56</td>
#       <td id="T_22cbd_row0_col4" class="data row0 col4" >3,422,718.91</td>
#     </tr>
#     <tr>
#       <th id="T_22cbd_level0_row1" class="row_heading level0 row1" >B2C</th>
#       <td id="T_22cbd_row1_col0" class="data row1 col0" >182,531.80</td>
#       <td id="T_22cbd_row1_col1" class="data row1 col1" >729,176.13</td>
#       <td id="T_22cbd_row1_col2" class="data row1 col2" >2,248,286.96</td>
#       <td id="T_22cbd_row1_col3" class="data row1 col3" >498,295.55</td>
#       <td id="T_22cbd_row1_col4" class="data row1 col4" >3,658,290.44</td>
#     </tr>
#     <tr>
#       <th id="T_22cbd_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_22cbd_row2_col0" class="data row2 col0" >399,997.85</td>
#       <td id="T_22cbd_row2_col1" class="data row2 col1" >1,447,638.65</td>
#       <td id="T_22cbd_row2_col2" class="data row2 col2" >4,133,027.74</td>
#       <td id="T_22cbd_row2_col3" class="data row2 col3" >1,100,345.11</td>
#       <td id="T_22cbd_row2_col4" class="data row2 col4" >7,081,009.35</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Creating lines on table

sales_customer.set_table_styles({
    'Total': [{
        'selector': 'th',
        'props': 'border-top: 1px solid #181818'
    },
    {
        'selector': 'td',
        'props': 'border-top: 1px solid #181818'
    }],
    
    'B2B': [{
        'selector': 'th',
        'props': 'border-top: 1px solid #181818'
    },
    {
        'selector': 'td',
        'props': 'border-top: 1px solid #181818'
    }]
}, overwrite=False, axis=1)
# Out:
# <style type="text/css">
# #T_22cbd td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_22cbd  th:not(.index_name) {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_22cbd .index_name {
#   font-weight: normal;
#   font-align: right;
#   font-style: italic;
#   color: #696969;
# }
# #T_22cbd th.row2 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd td.row2 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd th.row-1 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd td.row-1 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd th.row2 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd td.row2 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd th.row0 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd td.row0 {
#   border-top: 1px solid #181818;
# }
# </style>
# <table id="T_22cbd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_22cbd_level0_col0" class="col_heading level0 col0" >24 horas</th>
#       <th id="T_22cbd_level0_col1" class="col_heading level0 col1" >Econômica</th>
#       <th id="T_22cbd_level0_col2" class="col_heading level0 col2" >Entrega padrão</th>
#       <th id="T_22cbd_level0_col3" class="col_heading level0 col3" >Envio rápido</th>
#       <th id="T_22cbd_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22cbd_level0_row0" class="row_heading level0 row0" >B2B</th>
#       <td id="T_22cbd_row0_col0" class="data row0 col0" >217,466.05</td>
#       <td id="T_22cbd_row0_col1" class="data row0 col1" >718,462.52</td>
#       <td id="T_22cbd_row0_col2" class="data row0 col2" >1,884,740.78</td>
#       <td id="T_22cbd_row0_col3" class="data row0 col3" >602,049.56</td>
#       <td id="T_22cbd_row0_col4" class="data row0 col4" >3,422,718.91</td>
#     </tr>
#     <tr>
#       <th id="T_22cbd_level0_row1" class="row_heading level0 row1" >B2C</th>
#       <td id="T_22cbd_row1_col0" class="data row1 col0" >182,531.80</td>
#       <td id="T_22cbd_row1_col1" class="data row1 col1" >729,176.13</td>
#       <td id="T_22cbd_row1_col2" class="data row1 col2" >2,248,286.96</td>
#       <td id="T_22cbd_row1_col3" class="data row1 col3" >498,295.55</td>
#       <td id="T_22cbd_row1_col4" class="data row1 col4" >3,658,290.44</td>
#     </tr>
#     <tr>
#       <th id="T_22cbd_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_22cbd_row2_col0" class="data row2 col0" >399,997.85</td>
#       <td id="T_22cbd_row2_col1" class="data row2 col1" >1,447,638.65</td>
#       <td id="T_22cbd_row2_col2" class="data row2 col2" >4,133,027.74</td>
#       <td id="T_22cbd_row2_col3" class="data row2 col3" >1,100,345.11</td>
#       <td id="T_22cbd_row2_col4" class="data row2 col4" >7,081,009.35</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Changing elements on columns

sales_customer.set_table_styles({
    'Total': [{
        'selector': '.true',
        'props': 'background-color: #D8D8D8'
    }]
}, overwrite=False, axis=0)

colors_columns = pd.DataFrame(['false','true','false'], index = shipping_customer['Total'].index,
                             columns=['Total'])

sales_customer.set_td_classes(colors_columns)

# Changing elements on rows

sales_customer.set_table_styles({
    'Total': [{
        'selector': '.true',
        'props': 'background-color: #D8D8D8;'
    }]
}, overwrite=False, axis=1)

colors_rows =  pd.DataFrame([['false', 'false', 'true ', 'false', 'false']],
                            columns=shipping_customer.columns,
                            index=['Total'])

sales_customer.set_td_classes(colors_rows)
# Out:
# <style type="text/css">
# #T_22cbd td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_22cbd  th:not(.index_name) {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_22cbd .index_name {
#   font-weight: normal;
#   font-align: right;
#   font-style: italic;
#   color: #696969;
# }
# #T_22cbd th.row2 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd td.row2 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd th.row-1 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd td.row-1 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd th.row2 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd td.row2 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd th.row0 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd td.row0 {
#   border-top: 1px solid #181818;
# }
# #T_22cbd .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.row2 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.row2 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.row2 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.row2 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.row2 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_22cbd .true.row2 {
#   background-color: #D8D8D8;
# }
# </style>
# <table id="T_22cbd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_22cbd_level0_col0" class="col_heading level0 col0" >24 horas</th>
#       <th id="T_22cbd_level0_col1" class="col_heading level0 col1" >Econômica</th>
#       <th id="T_22cbd_level0_col2" class="col_heading level0 col2" >Entrega padrão</th>
#       <th id="T_22cbd_level0_col3" class="col_heading level0 col3" >Envio rápido</th>
#       <th id="T_22cbd_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22cbd_level0_row0" class="row_heading level0 row0" >B2B</th>
#       <td id="T_22cbd_row0_col0" class="data row0 col0" >217,466.05</td>
#       <td id="T_22cbd_row0_col1" class="data row0 col1" >718,462.52</td>
#       <td id="T_22cbd_row0_col2" class="data row0 col2" >1,884,740.78</td>
#       <td id="T_22cbd_row0_col3" class="data row0 col3" >602,049.56</td>
#       <td id="T_22cbd_row0_col4" class="data row0 col4 false" >3,422,718.91</td>
#     </tr>
#     <tr>
#       <th id="T_22cbd_level0_row1" class="row_heading level0 row1" >B2C</th>
#       <td id="T_22cbd_row1_col0" class="data row1 col0" >182,531.80</td>
#       <td id="T_22cbd_row1_col1" class="data row1 col1" >729,176.13</td>
#       <td id="T_22cbd_row1_col2" class="data row1 col2" >2,248,286.96</td>
#       <td id="T_22cbd_row1_col3" class="data row1 col3" >498,295.55</td>
#       <td id="T_22cbd_row1_col4" class="data row1 col4 true" >3,658,290.44</td>
#     </tr>
#     <tr>
#       <th id="T_22cbd_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_22cbd_row2_col0" class="data row2 col0 false" >399,997.85</td>
#       <td id="T_22cbd_row2_col1" class="data row2 col1 false" >1,447,638.65</td>
#       <td id="T_22cbd_row2_col2" class="data row2 col2 true " >4,133,027.74</td>
#       <td id="T_22cbd_row2_col3" class="data row2 col3 false" >1,100,345.11</td>
#       <td id="T_22cbd_row2_col4" class="data row2 col4 false" >7,081,009.35</td>
#     </tr>
#   </tbody>
# </table>
